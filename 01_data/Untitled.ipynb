# %%
import pandas as pd

# %%
df = pd.read_csv('AD01.csv', skiprows=67, nrows=23567, names=list_of_columns)
# 23567
# Out:
# /var/folders/jy/87nrhv716lq4zwb7ck6sngg80000gn/T/ipykernel_1729/4021196590.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('AD01.csv', skiprows=67, nrows=23567, names=list_of_columns)

# %%
df.head()
# Out:
#   prot_hit_num prot_acc                                       prot_desc  \
# 0            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 1            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 2            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 3            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 4            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
#
#    prot_score  prot_mass  prot_matches  prot_matches_sig  prot_sequences  \
# 0     34241.0    39886.0        1653.0            1200.0            43.0
# 1     34241.0    39886.0        1653.0            1200.0            43.0
# 2     34241.0    39886.0        1653.0            1200.0            43.0
# 3     34241.0    39886.0        1653.0            1200.0            43.0
# 4     34241.0    39886.0        1653.0            1200.0            43.0
#
#    prot_sequences_sig  prot_cover  ...  pep_ident  pep_expect  pep_res_before  \
# 0                33.0        73.6  ...       29.0        10.0               K
# 1                33.0        73.6  ...       29.0        19.0               K
# 2                33.0        73.6  ...       29.0        15.0               K
# 3                33.0        73.6  ...       29.0        17.0               K
# 4                33.0        73.6  ...       29.0        13.0               K
#
#    pep_seq  pep_res_after  pep_var_mod  pep_var_mod_pos  \
# 0    FLYHK              S          NaN              NaN
# 1    FLYHK              S          NaN              NaN
# 2    FLYHK              S          NaN              NaN
# 3    FLYHK              S          NaN              NaN
# 4    FLYHK              S          NaN              NaN
#
#                                       pep_scan_title  emPAI  emPAI_value
# 0  AD1_01.5569.5569.2 File:~AD1_01.raw~, NativeID...    NaN          NaN
# 1  AD1_02.5709.5709.2 File:~AD1_02.raw~, NativeID...    NaN          NaN
# 2  AD1_01.5723.5723.2 File:~AD1_01.raw~, NativeID...    NaN          NaN
# 3  AD1_02.5836.5836.2 File:~AD1_02.raw~, NativeID...    NaN          NaN
# 4  AD1_02.5992.5992.2 File:~AD1_02.raw~, NativeID...    NaN          NaN
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['prot_hit_num', 'prot_acc', 'prot_desc', 'prot_score', 'prot_mass',
#        'prot_matches', 'prot_matches_sig', 'prot_sequences',
#        'prot_sequences_sig', 'prot_cover', 'prot_len', 'prot_pi', 'pep_query',
#        'pep_rank', 'pep_isbold', 'pep_isunique', 'pep_exp_mz', 'pep_exp_mr',
#        'pep_exp_z', 'pep_calc_mr', 'pep_delta', 'pep_miss', 'pep_score',
#        'pep_homol', 'pep_ident', 'pep_expect', 'pep_res_before', 'pep_seq',
#        'pep_res_after', 'pep_var_mod', 'pep_var_mod_pos', 'pep_scan_title'],
#       dtype='object')

# %%
list_of_columns = []
for name in df.columns:
    list_of_columns.append(name)
list_of_columns.append('emPAI')
list_of_columns.append('emPAI_value')

# %%
list_of_columns
# Out:
# ['prot_hit_num',
#  'prot_acc',
#  'prot_desc',
#  'prot_score',
#  'prot_mass',
#  'prot_matches',
#  'prot_matches_sig',
#  'prot_sequences',
#  'prot_sequences_sig',
#  'prot_cover',
#  'prot_len',
#  'prot_pi',
#  'pep_query',
#  'pep_rank',
#  'pep_isbold',
#  'pep_isunique',
#  'pep_exp_mz',
#  'pep_exp_mr',
#  'pep_exp_z',
#  'pep_calc_mr',
#  'pep_delta',
#  'pep_miss',
#  'pep_score',
#  'pep_homol',
#  'pep_ident',
#  'pep_expect',
#  'pep_res_before',
#  'pep_seq',
#  'pep_res_after',
#  'pep_var_mod',
#  'pep_var_mod_pos',
#  'pep_scan_title',
#  'emPAI',
#  'emPAI_value']

# %%
df2 = pd.read_csv('AD02.csv', skiprows=67, nrows=23567, names=list_of_columns)
# Out:
# /var/folders/jy/87nrhv716lq4zwb7ck6sngg80000gn/T/ipykernel_1729/3418934922.py:1: DtypeWarning: Columns (0,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('AD02.csv', skiprows=67, nrows=23567, names=list_of_columns)

# %%
df2.head()
# Out:
#   prot_hit_num prot_acc                                       prot_desc  \
# 0            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 1            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 2            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 3            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 4            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
#
#   prot_score prot_mass prot_matches prot_matches_sig  prot_sequences  \
# 0      24722     39886         1292              908            39.0
# 1      24722     39886         1292              908            39.0
# 2      24722     39886         1292              908            39.0
# 3      24722     39886         1292              908            39.0
# 4      24722     39886         1292              908            39.0
#
#    prot_sequences_sig  prot_cover  ...  pep_ident  pep_expect  pep_res_before  \
# 0                29.0        71.9  ...       29.0        29.0               K
# 1                29.0        71.9  ...       29.0        15.0               K
# 2                29.0        71.9  ...       30.0        16.0               R
# 3                29.0        71.9  ...       30.0         8.1               R
# 4                29.0        71.9  ...       24.0         3.6               K
#
#      pep_seq  pep_res_after  pep_var_mod  pep_var_mod_pos  \
# 0      FLYHK              S          NaN              NaN
# 1      FLYHK              S          NaN              NaN
# 2  HHGPTITAK              L          NaN              NaN
# 3  HHGPTITAK              L          NaN              NaN
# 4    ECLQTCR              T          NaN              NaN
#
#                                       pep_scan_title  emPAI  emPAI_value
# 0  AD2_01.5861.5861.2 File:~AD2_01.raw~, NativeID...    NaN          NaN
# 1  AD2_01.5588.5588.2 File:~AD2_01.raw~, NativeID...    NaN          NaN
# 2  AD2_02.2222.2222.2 File:~AD2_02.raw~, NativeID...    NaN          NaN
# 3  AD2_01.2145.2145.2 File:~AD2_01.raw~, NativeID...    NaN          NaN
# 4  AD2_02.4097.4097.2 File:~AD2_02.raw~, NativeID...    NaN          NaN
#
# [5 rows x 34 columns]

# %%
df2.tail()
# Out:
#       prot_hit_num    prot_acc prot_desc  prot_score  \
# 23562          631  381.716379        2+  3120647.75
# 23563          632   381.71638        2+     2983871
# 23564          633  381.716382        2+  4086677.25
# 23565          634  381.716396        2+    72484608
# 23566          635  381.716396        2+     4931650
#
#                                                prot_mass prot_matches  \
# 23562  AD2_01.6479.6479.2 File:~AD2_01.raw~, NativeID...          NaN
# 23563  AD2_02.6436.6436.2 File:~AD2_02.raw~, NativeID...          NaN
# 23564  AD2_01.6327.6327.2 File:~AD2_01.raw~, NativeID...          NaN
# 23565  AD2_02.5981.5981.2 File:~AD2_02.raw~, NativeID...          NaN
# 23566  AD2_02.6279.6279.2 File:~AD2_02.raw~, NativeID...          NaN
#
#       prot_matches_sig  prot_sequences  prot_sequences_sig  prot_cover  ...  \
# 23562       1430.06928             NaN                 NaN         NaN  ...
# 23563       1400.45358             NaN                 NaN         NaN  ...
# 23564       1409.47668             NaN                 NaN         NaN  ...
# 23565       1339.35282             NaN                 NaN         NaN  ...
# 23566        1380.3411             NaN                 NaN         NaN  ...
#
#        pep_ident  pep_expect  pep_res_before  pep_seq  pep_res_after  \
# 23562        NaN         NaN             NaN      NaN            NaN
# 23563        NaN         NaN             NaN      NaN            NaN
# 23564        NaN         NaN             NaN      NaN            NaN
# 23565        NaN         NaN             NaN      NaN            NaN
# 23566        NaN         NaN             NaN      NaN            NaN
#
#        pep_var_mod  pep_var_mod_pos  pep_scan_title  emPAI  emPAI_value
# 23562          NaN              NaN             NaN    NaN          NaN
# 23563          NaN              NaN             NaN    NaN          NaN
# 23564          NaN              NaN             NaN    NaN          NaN
# 23565          NaN              NaN             NaN    NaN          NaN
# 23566          NaN              NaN             NaN    NaN          NaN
#
# [5 rows x 34 columns]

# %%
df.head()
# Out:
#   prot_hit_num prot_acc                                       prot_desc  \
# 0            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 1            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 2            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 3            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# 4            1   P02760  Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
#
#    prot_score  prot_mass  prot_matches  prot_matches_sig  prot_sequences  \
# 0     34241.0    39886.0        1653.0            1200.0            43.0
# 1     34241.0    39886.0        1653.0            1200.0            43.0
# 2     34241.0    39886.0        1653.0            1200.0            43.0
# 3     34241.0    39886.0        1653.0            1200.0            43.0
# 4     34241.0    39886.0        1653.0            1200.0            43.0
#
#    prot_sequences_sig  prot_cover  ...  pep_ident  pep_expect  pep_res_before  \
# 0                33.0        73.6  ...       29.0        10.0               K
# 1                33.0        73.6  ...       29.0        19.0               K
# 2                33.0        73.6  ...       29.0        15.0               K
# 3                33.0        73.6  ...       29.0        17.0               K
# 4                33.0        73.6  ...       29.0        13.0               K
#
#    pep_seq  pep_res_after  pep_var_mod  pep_var_mod_pos  \
# 0    FLYHK              S          NaN              NaN
# 1    FLYHK              S          NaN              NaN
# 2    FLYHK              S          NaN              NaN
# 3    FLYHK              S          NaN              NaN
# 4    FLYHK              S          NaN              NaN
#
#                                       pep_scan_title  emPAI  emPAI_value
# 0  AD1_01.5569.5569.2 File:~AD1_01.raw~, NativeID...    NaN          NaN
# 1  AD1_02.5709.5709.2 File:~AD1_02.raw~, NativeID...    NaN          NaN
# 2  AD1_01.5723.5723.2 File:~AD1_01.raw~, NativeID...    NaN          NaN
# 3  AD1_02.5836.5836.2 File:~AD1_02.raw~, NativeID...    NaN          NaN
# 4  AD1_02.5992.5992.2 File:~AD1_02.raw~, NativeID...    NaN          NaN
#
# [5 rows x 34 columns]

# %%
df.groupby(by='prot_desc')['emPAI_value'].sum()
# Out:
# prot_desc
# 1-phosphatidylinositol 4,5-bisphosphate phosphodiesterase eta-2 OS=Homo sapiens GN=PLCH2 PE=2 SV=3    0.02
# 14 kDa phosphohistidine phosphatase OS=Homo sapiens GN=PHPT1 PE=1 SV=1                                1.39
# 14-3-3 protein epsilon OS=Homo sapiens GN=YWHAE PE=1 SV=1                                             0.24
# 14-3-3 protein sigma OS=Homo sapiens GN=SFN PE=1 SV=1                                                 0.12
# 14-3-3 protein zeta/delta OS=Homo sapiens GN=YWHAZ PE=1 SV=1                                          0.12
#                                                                                                       ...
# WAP four-disulfide core domain protein 2 OS=Homo sapiens GN=WFDC2 PE=1 SV=2                           2.70
# WNT1-inducible-signaling pathway protein 2 OS=Homo sapiens GN=WISP2 PE=1 SV=1                         0.94
# Xylosyltransferase 1 OS=Homo sapiens GN=XYLT1 PE=1 SV=1                                               0.03
# Zinc-alpha-2-glycoprotein OS=Homo sapiens GN=AZGP1 PE=1 SV=2                                          0.20
# Zymogen granule protein 16 homolog B OS=Homo sapiens GN=ZG16B PE=1 SV=3                               0.15
# Name: emPAI_value, Length: 717, dtype: float64

# %%
AD01 = df.loc[df['emPAI_value'].notnull(),['prot_desc','emPAI_value']].T

# %%
AD01['Alzheimer\'s'] = 1

# %%
AD01.head()
# Out:
#                                                        1652  \
# prot_desc    Protein AMBP OS=Homo sapiens GN=AMBP PE=1 SV=1
# emPAI_value                                          637.85
#
#                                                        4095  \
# prot_desc    Serum albumin OS=Homo sapiens GN=ALB PE=1 SV=2
# emPAI_value                                          571.87
#
#                                                           4934  \
# prot_desc    Ig kappa chain C region OS=Homo sapiens GN=IGK...
# emPAI_value                                             606.48
#
#                                                           5276  \
# prot_desc    Prostaglandin-H2 D-isomerase OS=Homo sapiens G...
# emPAI_value                                              17.91
#
#                                                      5762  \
# prot_desc    Uromodulin OS=Homo sapiens GN=UMOD PE=1 SV=1
# emPAI_value                                         10.94
#
#                                                           5990  \
# prot_desc    Pancreatic alpha-amylase OS=Homo sapiens GN=AM...
# emPAI_value                                               8.47
#
#                                                           6200  \
# prot_desc    Alpha-amylase 1 OS=Homo sapiens GN=AMY1A PE=1 ...
# emPAI_value                                               7.48
#
#                                                           6398  \
# prot_desc    Basement membrane-specific heparan sulfate pro...
# emPAI_value                                               0.31
#
#                                                         6733  \
# prot_desc    Serotransferrin OS=Homo sapiens GN=TF PE=1 SV=3
# emPAI_value                                             20.8
#
#                                                           6949  ...  \
# prot_desc    Alpha-amylase 2B OS=Homo sapiens GN=AMY2B PE=1...  ...
# emPAI_value                                                8.0  ...
#
#                                                          23536  \
# prot_desc    Isoform 4 of Serpin A9 OS=Homo sapiens GN=SERP...
# emPAI_value                                               0.09
#
#                                                          23537  \
# prot_desc    Pituitary tumor-transforming gene 1 protein-in...
# emPAI_value                                               0.16
#
#                                                          23547  \
# prot_desc    Metalloproteinase inhibitor 1 OS=Homo sapiens ...
# emPAI_value                                               0.14
#
#                                                          23553  \
# prot_desc    Double-strand-break repair protein rad21 homol...
# emPAI_value                                               0.05
#
#                                                          23555  \
# prot_desc    Neurogenic locus notch homolog protein 2 OS=Ho...
# emPAI_value                                               0.01
#
#                                                          23558  \
# prot_desc    Dynamin-like 120 kDa protein, mitochondrial OS...
# emPAI_value                                               0.03
#
#                                                          23560  \
# prot_desc    Nuclear RNA export factor 1 OS=Homo sapiens GN...
# emPAI_value                                               0.05
#
#                                                          23562  \
# prot_desc    Protein kinase C alpha type OS=Homo sapiens GN...
# emPAI_value                                               0.04
#
#                                                          23565 Alzheimer's
# prot_desc    Exosome complex component RRP45 OS=Homo sapien...           1
# emPAI_value                                               0.07           1
#
# [2 rows x 718 columns]
